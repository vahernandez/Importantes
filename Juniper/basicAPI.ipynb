# %%
i/v2/pokemon/"  # un sitio que puedas hacer llamadas import requests
from pprint import pprint

url = "https://pokeapi.co/ap

# %%
resp = requests.get(url)

respjson = resp.json()

pprint(respjson)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# si quiero solo lo que esta en los cuadros rojos hago esto:

for i in respjson:
    print(i)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Si quiero algún cuadro celeste hago lo siguiente:
next = respjson['next']
print(next)
# Out:
# https://pokeapi.co/api/v2/pokemon/?offset=20&limit=20

# %%
# Si quiero todos los cuadros celestes:
for i in respjson.values():
    pprint(i)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Quiero la url de charmeleon:

for j in respjson['results']:
    if j['name']== 'charmeleon':
        print(j['url'])
# Out:
# https://pokeapi.co/api/v2/pokemon/5/

# %%
#Quiero todos los nombres de los pokemons:
for i in respjson['results']:
    print(i['name'] )

# %% [markdown]
# ![image.png](attachment:image.png)
