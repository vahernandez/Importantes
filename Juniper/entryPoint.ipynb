# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def factorial(n):
    c = n
    f = 1
    print(f'{c} != ', end= '')
    while(c> 0):
        if c>1:
            print(f'{c} x ', end = '')
        else:
            print(f'{c} = ', end= '')
        f*=c
        c -= 1
    print(f)
    return f

factorial(7)
# Out:
# 7 != 7 x 6 x 5 x 4 x 3 x 2 x 1 = 5040
# 5040
